# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np

# %%
basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9811401 entries, 0 to 9811400
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 673.7+ MB

# %% [markdown]
# ## Filtering/Cleaning

# %% [markdown]
# ### Title Basics

# %% [markdown]
# #### Replace "\N" with np.nan

# %%
basics['runtimeMinutes']= basics['runtimeMinutes'].replace('')

# %%
basics = basics.replace({'\\N':np.nan})

# %% [markdown]
# #### Eliminate movies that are null for runtimeMinutes and genre

# %%
basics.dropna(subset =['runtimeMinutes','genres'], inplace= True)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %% [markdown]
# #### Keep only titleType == Movie

# %%
basics_mov = basics[basics['titleType']== 'movie']
basics_mov.head()
# Out:
#         tconst titleType                    primaryTitle  \
# 8    tt0000009     movie                      Miss Jerry
# 144  tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570  tt0000574     movie     The Story of the Kelly Gang
# 587  tt0000591     movie                The Prodigal Son
# 672  tt0000679     movie  The Fairylogue and Radio-Plays
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 8                        Miss Jerry       0      1894     NaN             45
# 144   The Corbett-Fitzsimmons Fight       0      1897     NaN            100
# 570     The Story of the Kelly Gang       0      1906     NaN             70
# 587               L'enfant prodigue       0      1907     NaN             90
# 672  The Fairylogue and Radio-Plays       0      1908     NaN            120
#
#                          genres
# 8                       Romance
# 144      Documentary,News,Sport
# 570  Action,Adventure,Biography
# 587                       Drama
# 672           Adventure,Fantasy

# %% [markdown]
# #### keep startYear 2000-2022

# %%
basics_mov['startYear'].value_counts()
# Out:
# 2017    14367
# 2018    14322
# 2019    14056
# 2016    13950
# 2015    13476
#         ...
# 1904        1
# 1897        1
# 1896        1
# 2026        1
# 1894        1
# Name: startYear, Length: 130, dtype: int64

# %%
basics_year = basics_mov.loc[(basics_mov['startYear'] >= '2000') & (basics_mov['startYear'] <= '2022')]
basics_year
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 76059    tt0077684     movie
# ...            ...       ...
# 9811167  tt9916362     movie
# 9811251  tt9916538     movie
# 9811292  tt9916622     movie
# 9811319  tt9916680     movie
# 9811351  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 76059                    Histórias de Combóios em Portugal
# ...                                                    ...
# 9811167                                              Coven
# 9811251                                Kuambil Lagi Hatiku
# 9811292        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9811319  De la ilusión al desconcierto: cine colombiano...
# 9811351                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0      2021
# 34803                                       Kate & Leopold       0      2001
# 61116            El tango del viudo y su espejo deformante       0      2020
# 67669                           The Other Side of the Wind       0      2018
# 76059                    Histórias de Combóios em Portugal       0      2022
# ...                                                    ...     ...       ...
# 9811167                                           Akelarre       0      2020
# 9811251                                Kuambil Lagi Hatiku       0      2019
# 9811292        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9811319  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9811351                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                  genres
# 13082       NaN             94             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 76059       NaN             46             Documentary
# ...         ...            ...                     ...
# 9811167     NaN             92           Drama,History
# 9811251     NaN            123                   Drama
# 9811292     NaN             57             Documentary
# 9811319     NaN            100             Documentary
# 9811351     NaN             49             Documentary
#
# [223107 rows x 9 columns]

# %% [markdown]
# #### Eliminate movies that include "Documentary" in genre

# %%
doc = basics_year['genres'].str.contains('Documentary',case=False)
basics_doc = basics_year[~doc]

# %%
basics_doc.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34803  tt0035423     movie                                     Kate & Leopold
# 61116  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67669  tt0069049     movie                         The Other Side of the Wind
# 77964  tt0079644     movie                                      November 1828
# 86801  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult startYear endYear  \
# 34803                             Kate & Leopold       0      2001     NaN
# 61116  El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                 The Other Side of the Wind       0      2018     NaN
# 77964                              November 1828       0      2001     NaN
# 86801                          The Naked Monster       0      2005     NaN
#
#       runtimeMinutes                  genres
# 34803            118  Comedy,Fantasy,Romance
# 61116             70                   Drama
# 67669            122                   Drama
# 77964            140               Drama,War
# 86801            100    Comedy,Horror,Sci-Fi

# %%
basics_doc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147367 entries, 34803 to 9811251
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          147367 non-null  object
#  1   titleType       147367 non-null  object
#  2   primaryTitle    147367 non-null  object
#  3   originalTitle   147367 non-null  object
#  4   isAdult         147367 non-null  object
#  5   startYear       147367 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  147367 non-null  object
#  8   genres          147367 non-null  object
# dtypes: object(9)
# memory usage: 11.2+ MB

# %% [markdown]
# ### AKA

# %% [markdown]
# #### keep only US movies

# %%
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas_us = akas[akas['region']== 'US']
akas_us.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US       \N  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 33  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#                attributes isOriginalTitle
# 5                      \N               0
# 14  literal English title               0
# 33                     \N               0
# 36                     \N               0
# 41                     \N               0

# %% [markdown]
# #### Replace '\N' with np.nan

# %%
akas_us = akas_us.replace({'\\N':np.nan})

# %%
akas_us.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
akas_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1433173 entries, 5 to 35743985
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1433173 non-null  object
#  1   ordering         1433173 non-null  int64
#  2   title            1433173 non-null  object
#  3   region           1433173 non-null  object
#  4   language         3893 non-null     object
#  5   types            978227 non-null   object
#  6   attributes       46470 non-null    object
#  7   isOriginalTitle  1431828 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 98.4+ MB

# %% [markdown]
# ### Ratings

# %%
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1808
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2607

# %% [markdown]
# #### Replace '\N' with np.nan

# %%
ratings = ratings.replace({'\\N':np.nan})

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306416 entries, 0 to 1306415
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1306416 non-null  object
#  1   averageRating  1306416 non-null  float64
#  2   numVotes       1306416 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.9+ MB

# %% [markdown]
# ### Filtered one dataset with another

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics_doc['tconst'].isin(akas_us['titleId'])
keepers
# Out:
# 34803       True
# 61116       True
# 67669       True
# 77964      False
# 86801       True
#            ...
# 9811074     True
# 9811083     True
# 9811122    False
# 9811167     True
# 9811251    False
# Name: tconst, Length: 147367, dtype: bool

# %%
basics = basics_doc[keepers]
basics
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 86801    tt0088751     movie
# 93938    tt0096056     movie
# ...            ...       ...
# 9810539  tt9914942     movie
# 9810934  tt9915872     movie
# 9811074  tt9916170     movie
# 9811083  tt9916190     movie
# 9811167  tt9916362     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 86801                                    The Naked Monster
# 93938                                 Crime and Punishment
# ...                                                    ...
# 9810539                             Life Without Sara Amat
# 9810934                               The Last White Witch
# 9811074                                      The Rehearsal
# 9811083                                          Safeguard
# 9811167                                              Coven
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 86801                            The Naked Monster       0      2005     NaN
# 93938                         Crime and Punishment       0      2002     NaN
# ...                                            ...     ...       ...     ...
# 9810539                 La vida sense la Sara Amat       0      2019     NaN
# 9810934                  My Girlfriend is a Wizard       0      2019     NaN
# 9811074                                   O Ensaio       0      2019     NaN
# 9811083                                  Safeguard       0      2020     NaN
# 9811167                                   Akelarre       0      2020     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 86801              100       Comedy,Horror,Sci-Fi
# 93938              126                      Drama
# ...                ...                        ...
# 9810539             74                      Drama
# 9810934             97       Comedy,Drama,Fantasy
# 9811074             51                      Drama
# 9811083             95  Action,Adventure,Thriller
# 9811167             92              Drama,History
#
# [86563 rows x 9 columns]

# %% [markdown]
# ## Data was collected from TMBD
# https://www.themoviedb.org/about/logos-attribution
